# %%
# !git clone https://github.com/cszn/DnCNN.git
# %cd DnCNN
# Out:
# Cloning into 'DnCNN'...
# remote: Enumerating objects: 946, done.
# remote: Counting objects: 100% (12/12), done.
# remote: Compressing objects: 100% (12/12), done.
# remote: Total 946 (delta 6), reused 0 (delta 0), pack-reused 934
# Receiving objects: 100% (946/946), 127.72 MiB | 21.70 MiB/s, done.
# Resolving deltas: 100% (184/184), done.
# Updating files: 100% (841/841), done.
# /content/DnCNN

# %%
# !cp /content/drive/MyDrive/projet_imagerie/DPIR/model/drunet_color.pth /content/DPIR/model_zoo
# !mkdir /content/DPIR/testsets/bsd68
# !cp /content/drive/MyDrive/projet_imagerie/data/base_images/* /content/DPIR/testsets/bsd68
